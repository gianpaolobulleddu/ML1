# %% [markdown]
# # Overfitting
#
# One of the most important issues in Machine Learning is to understand the difference between training and testing errors. The training process will allow the ANN parameters (weights and bias) to be modified to minimise the loss in the **set of patterns used for training**.  If this set of patterns is sufficiently representative, then the ANN will perform well in its working environment, i.e. with new patterns that are not in the training set.  On the other hand, if this set of patterns has not been well chosen, the ANN could not work well with new patterns.  The only way to know this is precisely to evaluate the ANN with new patterns and calculate the error with these **test patterns**.  Since the test set is available from the beginning, this evaluation with the test set is done at the same time as with the training set (but only the training set is used for training).
#
# Therefore, to assess how well trained an ANN is, this can be done by evaluating the test set, not the training set.  Usually there is only one set of data, so it is usually divided into two subsets: training and test. There are several alternatives to perform this division; in these tutorials, two different ones will be performed:
#
# * **Hold Out**. In this method, an experiment is performed with a simple partition of the data set, leaving a certain percentage for testing, usually between 20% and 30%.
#
# * **Cross-validation**.  Here, the data set is divided into $k$ disjoint subsets in order to perform the corresponding $k$ experiments.  In the k-th experiment, the $k$-th set is separated for testing, and trained with the remaining $k-1$.  A usual value of $k$ is 10, so you have a 10-fold crossvalidation.
#
# More specifically, in this session we will focus on the first one, leaving the second one for a later one.  The hold out technique allows us to split the data set into two subsets: training and test.  The training subset allows to adjust the parameters of the model (connection weights and bias), while the test subset allows to check (test) the behavious of a trained ANN (or, any kind of model that is being used, such as a decision tree) on new patterns, not present in the training set.
#
# ![Normal training in the left, and an overfitting curve on the right](./img/Overfitting.png)
#
# Given a well-chosen (and therefore sufficiently representative) training set, the training process could be similar to the figure on the left, with both training and test errors decreasing with each cycle. However, in general, it cannot be ensured that the training set is as noise-free and well-chosen as desirable, so that **overtraining** or **overfitting** often occurs during training.  This can be clearly seen in the figure on the right, where both errors are decreasing until a point is reached where the test error starts to increase.   From that point on, the system starts to overfit.
#
# To avoid overfitting, in ANNs there are a series of techniques known as regularisation techniques, each of which is very different in nature, but all of which aim to avoid overtraining.  Although these techniques are dealt with in much greater depth in other subjects in the programme, e.g. Deep Learning I, in these tutorials we are going to study one of the most well-known techniques, seen in the theory session, called Early Stopping.
#
# In this technique, instead of dividing the initial set of samples into 2 subsets, we create 3 subsets: training, validation and test.  The training and test sets perform the functions described above. The purpose of the validation set is to avoid overfitting by controlling the training process, but it is not used to modify weights or bias.  There are several ways to control the training process, here we will use two of them together:
#
# * A new criteria for stopping the training process.   With the definition of a new parameter: the maximum number of consecutive cycles without improving the *loss* in the validation set.  If these cycles elapse without improving the best validation *loss* achieved so far, the training is stopped.  As the validation set is not used to modify weights or bias, it gives an estimate of what the test error could be.  Therefore, when the validation error increases, it increases the error in patterns that it has not seen, so it is estimated that the test error would increase, and the network would be overtraining.
#
#
# * Once the training process has stopped, the validation set determines which network is returned.  During all the training cycles, the loss is calculated in the training set, which is necessary to modify weights and bias, but also in the validation set.   Once the training is stopped, the ANN is returned corresponding not to the last cycle, but to the cycle with the lowest error in the validation set.  This is done because it is estimated that this ANN is the one that will give the lowest error in the test set, i.e. the one that will behave better with new patterns and, consequently, the one that will generalise better.
#
# Once the training process has stopped and an ANN has been returned, the test set can be evaluated to assess how well the ANN has been trained.
#
# > **Important**: The errors (or accuracies, or any metric used) in the training and validation sets are interesting, but the one that really matters is the test set.
#
# However, most of the time you have all 3 sets (training, validation and test) from the beginning, so as you evaluate the training and validation sets, you also evaluate the test set, which is useful for plotting graphs. However, these values in the test set cannot be used for decision making.

# %% [markdown]
# ### Question 3.1
# > ❓ If what we want to achieve is an ANN with the lowest possible test error, why not choose the ANN corresponding to the cycle with the lowest test error?

# %% [markdown]
# `Because the test set must never be used during training or model selection. Its purpose is to provide an unbiased estimate of how the ANN will perform on unseen, real-world data.
# If we want an ANN with the lowest possible test error, we cannot choose the model based on the test set because the test set must only be used at the very end, to give an unbiased estimate of performance on unseen data. If we pick the model with the lowest test error during training, we are leaking information from the test set into the training process. This leads to overfitting to the test data and gives an unrealistically optimistic estimate of generalization. The correct procedure is to train on the training set, use the validation set to select the best model or apply early stopping, and then evaluate the chosen model on the test set only once.`

# %% [markdown]
# Therefore, in the training loop it is necessary to keep a reference to the best validation error found so far.  It is also necessary to keep a copy of the ANN that has given that validation error.  Both elements should be updated every cycle when the validation error improves. It is also necessary to keep a counter of how many consecutive cycles the validation error has not improved.
#
# As can be seen, the test set cannot have any involvement in the training process. This is the right thing to do, since an ANN with completely new patterns is being evaluated. However, from a very strict point of view, there is one part in this whole process where the test set is having a small influence: in the normalisation of the data.
#
# Usually the starting point is a dataset that is first normalised and then split into training/test.  If this is done in this way, the patterns used for testing have some influence on the calculation of the normalisation parameter values, which would not be correct. However, the impact they usually have on these parameters and in general on the performance of the ANN is so low, that this is usually not taken into account and all patterns are normalised together.  In any case, the really correct pipeline to do would be divide the data into train test, to calculate the values of the normalisation parameters only with the training set, and the applied that parameters of normalization to the test prior to run the usual training process. Addtionally, if there is a validation data, it can be used on the normalization, too.
#
# For this assignment, you are asked to perform two sets of experiments, one without using validation and the other using a validation set.  More specifically, the requirements are:
#
# 1. Develop a function called `holdOut` that given two parameters, `N` (equal to the number of patterns) and `P` (value between 0 and 1, indicating the percentage of patterns that will be separated for the test set), returns a tuple with two vectors with the indices of the patterns that will be used for training and testing.  The sum of lengths of both vectors has to be equal to N, and these two vectors have to be disjoint.
#
#   This function can be done in a very simple way using the function `randperm` (to use it, load the module with `using Random`).
#
#   From this function, splitting a database into two subsets is done immediately.

# %% [markdown]
# # 📘  Imports

# %%
using Random
using Statistics
using Plots
using Flux 
using Flux.Losses
using DelimitedFiles;

using Pkg; 
#Pkg.add("Plots") # --- Uncomment if Plots is not installed

# %% [markdown]
# # 📘  holdOut(N::Int, P::Real)

# %%
function holdOut(N::Int, P::Real)
    #TODO
    @assert(0.0 < P < 1.0 , "P must be in (0,1)")
    #idx = shuffle(1:N)
    idx = randperm(N)
    println("idx indices: ", idx)
    nTrain = Int(floor((1-P)*N))
    trainIdx = idx[1:nTrain]
    testIdx = idx[nTrain+1:end]
    return (trainIdx, testIdx)
end;
trainIdx, testIdx = holdOut(10, 0.1);
println("Train indices: ", trainIdx)
println("Test indices: ", testIdx)
# Out:
# idx indices: [2, 7, 9, 4, 10, 1, 6, 8, 3, 5]
# Train indices: [2, 7, 9, 4, 10, 1, 6, 8, 3]
# Test indices: [5]

# %% [markdown]
# 2. Develop another function called `holdOut`, the same as the previous one and, based on it, which takes 3 parameters: `N` (number of patterns), `Pval` (rate of patterns in the validation set) and `Ptest` (rate of patterns in the test set), and returns a tuple with 3 vectors, with the indices of the elements of the training, validation and test sets. The sum of the lengths of these 3 vectors has to be equal to `N`.
#
#  To do this, simply make two calls to the previously developed `holdOut` function.

# %% [markdown]
# # 📘  holdOut(N::Int, Pval::Real, Ptest::Real)

# %%
function holdOut(N::Int, Pval::Real, Ptest::Real)     
    @assert(0.0 < Pval < 1.0 , "Pval must be in (0,1)")
    @assert(0.0 < Ptest < 1.0 , "Ptest must be in (0,1)")
    @assert(Pval+Ptest < 1.0 , "Pval + Ptest must be in lower than 1")

    train_val_idx, test_idx = holdOut(N, Ptest)

    # Compute the absolute number of validation samples as Pval * N (rounded down)
    nVal = Int(floor(Pval*N))          
    # Compute the total number of samples available for training + validation (everything except the test set)
    nTrainVal = Int(floor((1-Ptest)*N)) 
    # Recalculate the validation proportion relative to the train+validation pool
    Pval2 = nVal/nTrainVal             

    local_train_idx, local_val_idx = holdOut(length(train_val_idx), Pval2)

    # Map from local indices back to the global indices
    train_idx = train_val_idx[local_train_idx]
    val_idx   = train_val_idx[local_val_idx]

    return (train_idx, val_idx, test_idx)
end;

trainIdx, valIdx, testIdx = holdOut(10, 0.3, 0.3);
println("Train indices: ", trainIdx)
println("Validation indices: ", valIdx)
println("Test indices: ", testIdx)
# Out:
# idx indices: [7, 1, 2, 9, 3, 10, 5, 6, 4, 8]
# idx indices: [5, 1, 2, 7, 3, 4, 6]
# Train indices: [3, 7, 1, 5]
# Validation indices: [2, 9, 10]
# Test indices: [6, 4, 8]

# %% [markdown]
# 3. Modify the function for training the ANN developed in the previous session to accept the following *optional* parameters in addition to those defined in the previous practice:
#   - **Validation set**, of type `Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}`, i.e. a tuple of 2 arrays: inputs and targets. Default value to empty arrays.
#   - **Test set**, of type `Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}`, i.e. a tuple of 2 arrays: inputs and targets. Default value to empty arrays.
#   - **maxEpochsVal**, of type `Int`, which defines the number of cycles without improving the best validation loss found so far that have to elapse to stop training. In other words, it defines a new stop criterion. Default value should be set to 20.
#
#   With these parameters, this function should implement the early stopping strategy, for which it is necessary to take care that the ANN returned at the end of the function must be:
#     - If a validation set has been given as a argument (i.e. if it is not empty), the ANN to be returned does not have to be the one being trained, but the one with the best validation error.
#     - If no validation set has been passed as a parameter (i.e. if it is empty), the ANN to be returned should be the one corresponding to the last training cycle.  Consequently, the new training function should work in the same way as the previous one in case no validation set is given.
#
#   Additionally, from the trained ANN, this function should return a history of the loss values obtained in the training, validation and test sets in each cycle, as a vector each.
#
#   - To add elements to the end of a vector, refer to the function `push!`
#   - It should be noted that the loss values obtained with the ANN with random weights, prior to training, are usually considered as cycle 0.
#
#   As stated in the previous description, it will be necessary to store the best ANN achieved so far and update it in some iterations of the loop.  To do this, you cannot simply make an assignment to a new variable, since you would only assign the pointer, which would point to the same memory address with the ANN that would be modified in the next iteration.  To make a copy of an object in such a way that all objects (and data, as in this case weights and bias) it contains are also copied, recursively, you can use the function `deepcopy`.

# %% [markdown]
# # 📘 trainClassANN

# %%
function trainClassANN(topology::AbstractArray{<:Int,1},  
            trainingDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}; 
            # --- Requirement: optional validation dataset with default empty arrays ---
            validationDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}= 
                    (Array{eltype(trainingDataset[1]),2}(undef,0,0), falses(0,0)), 
            # --- Requirement: optional test dataset with default empty arrays ---
            testDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}= 
                    (Array{eltype(trainingDataset[1]),2}(undef,0,0), falses(0,0)), 
            transferFunctions::AbstractArray{<:Function,1}=fill(σ, length(topology)), 
            maxEpochs::Int=1000, minLoss::Real=0.0, learningRate::Real=0.01,  
            # --- Requirement: maxEpochsVal parameter (early stopping patience), default 20 ---
            maxEpochsVal::Int=20, showText::Bool=false) 

    # --- Unpacking datasets ---
    (inputs, targets) = trainingDataset
    (val_inputs, val_targets) = validationDataset
    (test_inputs, test_targets) = testDataset

    # --- Ensures dataset dimensions match ---
    @assert size(inputs,1) == size(targets,1)
    @assert size(val_inputs,1) == size(val_targets,1)
    @assert size(test_inputs,1) == size(test_targets,1)

    # --- Requirement: build ANN with given topology ---
    ann = buildClassANN(size(inputs,2), topology, size(targets,2))

    # --- Define loss function (binary or multi-class) ---
    # discriminates based on the number of output neurons
    loss(model,x,y) = (size(y,1) == 1) ? Losses.binarycrossentropy(model(x),y) : Losses.crossentropy(model(x),y)

    # --- Requirement: loss histories for training/validation/test ---
    trainingLosses = Float32[]
    validationLosses = Float32[]
    testLosses = Float32[]

    # --- Initial losses (cycle 0, before training) ---
    numEpoch = 0
    trainingLoss = loss(ann, inputs', targets')
    push!(trainingLosses, trainingLoss)
    
    # init message buffer
    log_message = []
    log_message = "Epoch $numEpoch - loss: $(round(trainingLoss, digits=4))"


    # --- if validation set is provided ---                          
    if size(val_inputs,1) > 0
        validationLoss = loss(ann, val_inputs', val_targets')
        push!(validationLosses, validationLoss)

        # update message buffer
        log_message *= " - val_loss: $(round(validationLoss, digits=4))"
    end

     # --- if test set is provided ---  
    if size(test_inputs,1) > 0
        testLoss = loss(ann, test_inputs', test_targets')
        push!(testLosses, testLoss)
        # update message buffer
        log_message *= " - test_loss: $(round(testLoss, digits=4))"
        if showText
            # do nothing
            #println("Epoch ", numEpoch, ": test loss: ", testLoss)
        end
    end

    if showText
        # print message buffer
        println(join(log_message))
    end
    # --- Optimizer setup ---
    opt_state = Flux.setup(Adam(learningRate), ann)

    # --- Requirement: variables for early stopping ---
    epochsWithoutImprovement = 0
    bestValLoss = Inf
    bestAnn = deepcopy(ann)  # Requirement: store best ANN (deepcopy to avoid overwriting)
    bestAnnEpoch = 0

    while (numEpoch < maxEpochs) && (trainingLoss > minLoss) && (epochsWithoutImprovement < maxEpochsVal)
        Flux.train!(loss, ann, [(inputs', targets')], opt_state)
        numEpoch += 1
        log_message = []
        # --- Compute training loss and store it ---
        trainingLoss = loss(ann, inputs', targets')
        push!(trainingLosses, trainingLoss)
        
        # update message buffer
        log_message = "Epoch $numEpoch - loss: $(round(trainingLoss, digits=4))"

        outputs=ann(inputs')
        outputs=classifyOutputs(outputs')
        predicted_classes = Flux.onecold(outputs')        # vector of predicted labels
        true_classes = Flux.onecold(targets')      # vector of true labels

        accuracy_train=accuracy(predicted_classes, true_classes)

        log_message *= " - acc: $(round(accuracy_train, digits=4))"

        # --- Requirement: if validation set provided, track its loss for early stopping ---
        if size(val_inputs,1) > 0
            validationLoss = loss(ann, val_inputs', val_targets')
            push!(validationLosses, validationLoss)

            # update message buffer
            log_message *= " - val_loss: $(round(validationLoss, digits=4))"

            outputs=ann(val_inputs')
            outputs=classifyOutputs(outputs')
            predicted_classes = Flux.onecold(outputs')        # vector of predicted labels
            true_classes = Flux.onecold(val_targets')      # vector of true labels

            accuracy_val=accuracy(predicted_classes, true_classes)

            log_message *= " - val_acc: $(round(accuracy_val, digits=4))"

            if validationLoss < bestValLoss
                bestValLoss = validationLoss
                epochsWithoutImprovement = 0
                bestAnn = deepcopy(ann)   # Requirement: update best ANN when improvement found
                bestAnnEpoch = numEpoch
            else
                epochsWithoutImprovement += 1
            end
        end

        # --- Requirement: also track test loss if provided ---
        if size(test_inputs,1) > 0
            testLoss = loss(ann, test_inputs', test_targets')
            push!(testLosses, testLoss)
            

            # update message buffer
            log_message *= " - test_loss: $(round(testLoss, digits=4))"

            outputs=ann(test_inputs')
            outputs=classifyOutputs(outputs')
            predicted_classes = Flux.onecold(outputs')        # vector of predicted labels
            true_classes = Flux.onecold(test_targets')      # vector of true labels

            accuracy_test=accuracy(predicted_classes, true_classes)
            test_error = 1-accuracy_test

            log_message *= " - test_acc: $(round(accuracy_test, digits=4))"
            log_message *= " - test_error: $(round(test_error, digits=4))"

        end
        
        if showText
            # update message buffer
            log_message *= " - epochsWithoutImprovement $(epochsWithoutImprovement)"
            println(join(log_message))
        end

        #print("trainingLoss > minLoss : $(trainingLoss > minLoss) \n")
        #print("epochsWithoutImprovement < maxEpochsVal : $(epochsWithoutImprovement < maxEpochsVal) \n")
    end  # closes while
    
    # --- Early stopping notice ---
    if (epochsWithoutImprovement >= maxEpochsVal) && showText
        println("⏹ Early stopping triggered after $numEpoch epochs (no improvement for $maxEpochsVal epochs).")
    end

    # --- Requirement: return the right ANN ---
    # If validation set was provided → return best ANN found
    # Otherwise → return last trained ANN
    finalAnn = size(val_inputs,1) > 0 ? bestAnn : ann

    bestEpoch = size(val_inputs,1) > 0 ? bestAnnEpoch : maxEpochs
    println("The ANN corespond to the epoch $bestEpoch")

    return finalAnn, trainingLosses, validationLosses, testLosses
end  # closes function
# Out:
# trainClassANN (generic function with 1 method)

# %% [markdown]
# 4. Since there were two versions of the ANN training function (the second accepted a vector as desired outputs), modify this function in the same way so that the targets are vectors instead of arrays for the two-class classification case. Note that in this case the types of the training, validation and test sets passed as parameters will be `Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,1}}` for all three and therefore it will be necessary to call the function `reshape` on all three.

# %% [markdown]
# # 📘 trainClassANN (Overload)

# %%
function trainClassANN(topology::AbstractArray{<:Int,1},  
        trainingDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,1}}; 
        validationDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,1}}= 
                    (Array{eltype(trainingDataset[1]),2}(undef,0,0), falses(0)), 
        testDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,1}}= 
                    (Array{eltype(trainingDataset[1]),2}(undef,0,0), falses(0)), 
        transferFunctions::AbstractArray{<:Function,1}=fill(σ, length(topology)), 
        maxEpochs::Int=1000, minLoss::Real=0.0, learningRate::Real=0.01,  
        maxEpochsVal::Int=20, showText::Bool=false)

    (inputs, targets) = trainingDataset
    (val_inputs, val_targets) = validationDataset
    (test_inputs, test_targets) = testDataset
    
    # This function assumes that each sumple is in a row
    # we are going to check the numeber of samples to have same inputs and targets
    @assert(size(inputs,1)==size(targets,1));
    @assert (size(val_inputs,1) == size(val_targets,1));
    @assert (size(test_inputs,1) == size(test_targets,1));

    trainClassANN(topology, 
        (inputs, reshape(targets, length(targets), 1)),
        (val_inputs, reshape(val_targets, length(val_targets), 1)), 
        (test_inputs, reshape(test_targets, length(test_targets), 1)),
        transferFunctions, 
        maxEpochs=maxEpochs, minLoss=minLoss, learningRate=learningRate,
        maxEpochsVal, showText);
end;

# %% [markdown]
# Remember to integrate the code developed in previous sessions to validate the following pipeline:
#
# 1. Load the database, having the patterns in rows and desired attributes and outputs in columns.
#
# 2. Use the function `holdOut` to split the data set into training, validation and test with the desired percentages. These percentages can be equal to 0.  You will therefore have 6 matrices: inputs and targets in training, validation and test (some may be empty if the corresponding percentage is 0).
#
# 3. Calculate the parameter values corresponding to the type of normalisation to be used with your data (maximum/minimum or mean/standard deviation for each attribute) from the training set only.
#   * This part does not ask to normalise the training set, but to calculate the normalisation values from the training set.
# 4. With these parameters for normalisation calculated in the previous step, normalise training, validation and test sets.
# 5. Train different architectures, and, for each one of them, draw graphs of the evolution of the training, validation and test loss values in the same graph, including cycle 0.

# %% [markdown]
# # Functions

# %%
#Develop here the corresponding code and/or in an external file
#You can load instead of copy and paste
#TODO
#--------------------------------------------------------------------------------
## Normalization functions
#--------------------------------------------------------------------------------
function calculateMinMaxNormalizationParameters(dataset::AbstractArray{<:Real,2})
    return minimum(dataset, dims=1), maximum(dataset, dims=1)
end;

#
function normalizeMinMax!(dataset::AbstractArray{<:Real,2},      
        normalizationParameters::NTuple{2, AbstractArray{<:Real,2}})
    minValues = normalizationParameters[1];
    maxValues = normalizationParameters[2];
    dataset .-= minValues;
    dataset ./= (maxValues .- minValues);
    # eliminate any atribute that do not add information
    dataset[:, vec(minValues.==maxValues)] .= 0;
    return dataset;
end;


function normalizeMinMax!(dataset::AbstractArray{<:Real,2})
    normalizeMinMax!(dataset , calculateMinMaxNormalizationParameters(dataset));
end;

function normalizeMinMax( dataset::AbstractArray{<:Real,2},      
                normalizationParameters::NTuple{2, AbstractArray{<:Real,2}}) 
    normalizeMinMax!(copy(dataset), normalizationParameters);
end;

#--------------------------------------------------------------------------------
## One-hot encoding function
#--------------------------------------------------------------------------------
function oneHotEncoding(feature::AbstractArray{<:Any,1},      
        classes::AbstractArray{<:Any,1})

    """
    Parameters
    ----------
    feature :: AbstractVector
        The input vector of categorical values to be encoded.
    classes :: AbstractVector
        The list/array of unique classes used as encoding reference.
    """
    """
    AbstractArray{<:Any,1} :
    AbstractArray → not restricted to just Vector, could be any 1-dimensional array type.
    1 → one-dimensional array (i.e. a vector).
    <:Any → element type can be any subtype of Any (which basically means no restriction at all).
    So effectively, AbstractArray{<:Any,1} is just a very general way of saying:
    👉 “Accept any 1-D array, regardless of element type.”
    """
    # Defensive: ensure feature is a vector
    # Check that all feature values exist in the set of classes
    @assert(all([in(value, classes) for value in feature]))
    
    # Number of classes
    numClasses = length(classes)
    
    # Defensive: require at least two classes
    @assert(numClasses > 1)
    
    if (numClasses == 2)
        # Special case: binary classification, use a single column
        oneHot = reshape(feature .== classes[1], :, 1)
    else
        # General case: more than two classes
        oneHot = BitArray{2}(undef, length(feature), numClasses)
        for numClass = 1:numClasses
            # Mark 1 where feature matches the class
            oneHot[:, numClass] .= (feature .== classes[numClass])
        end
    end


    """
    Returns
    -------
    AbstractArray
        A one-hot encoded array:
        - Shape (n, 1) if there are 2 classes (binary case).
        - Shape (n, numClasses) if there are more than 2 classes.
    """
    return oneHot
end

#--------------------------------------------------------------------------------
## ANN building function
#--------------------------------------------------------------------------------
function buildClassANN(numInputs::Int, topology::AbstractArray{<:Int,1}, numOutputs::Int;
                    transferFunctions::AbstractArray{<:Function,1}=fill(σ, length(topology))) 
    ann=Chain();
    numInputsLayer = numInputs;
    for numHiddenLayer in 1:length(topology)
        numNeurons = topology[numHiddenLayer];
        ann = Chain(ann..., Dense(numInputsLayer, numNeurons, transferFunctions[numHiddenLayer]));
        numInputsLayer = numNeurons;
    end;
    if (numOutputs == 1)
        ann = Chain(ann..., Dense(numInputsLayer, 1, σ));
    else
        ann = Chain(ann..., Dense(numInputsLayer, numOutputs, identity));
        ann = Chain(ann..., softmax);
    end;
    return ann;
end;   

function classifyOutputs(outputs::AbstractArray{<:Real,2}; 
                        threshold::Real=0.5) 
   numOutputs = size(outputs, 2);
    @assert(numOutputs!=2)
    if numOutputs==1
        return outputs.>=threshold;
    else
        # Look for the maximum value using the findmax funtion
        (_,indicesMaxEachInstance) = findmax(outputs, dims=2);
        # Set up then boolean matrix to everything false while max values aretrue.
        outputs = falses(size(outputs));
        outputs[indicesMaxEachInstance] .= true;
        # Defensive check if all patterns are in a single class
        @assert(all(sum(outputs, dims=2).==1));
        return outputs;
    end;
end;

function accuracy(outputs::Vector{Int64}, targets::Vector{Int64}) 
    mean(outputs.==targets);
end;

# %% [markdown]
# # Data Load and Normalization

# %%
# 1. Load the database
dataset = readdlm("./data/iris.data",',');

"""
2. Use the function `holdOut` to split the data set into training, validation and test with the desired percentages. 
    These percentages can be equal to 0. 
    You will therefore have 6 matrices:
    inputs and targets in training, 
    validation and test (some may be empty if the corresponding percentage is 0). 
"""



trainIdx, valIdx, testIdx = holdOut(size(dataset, 1), 0.3, 0.3)
println("Train indices: ", length(trainIdx))
println("Validation indices: ", length(valIdx))
println("Test indices: ", length(testIdx))
println("Dataset size: ", size(dataset))



# 1.1. Prepare the data
inputs = convert(Array{Float32,2}, dataset[:,1:4]);
targets = dataset[:,5];
classes = unique(targets);

println("targets \n $targets \n size$(size(targets))")
println("classes \n $classes \n num classes : $(length(classes))")


# 1.2 One-hot encode targets
targets_oh = oneHotEncoding(targets, classes)
println("One-hot encoded targets size: ", size(targets_oh))


# 1.3 Create training, validation, and test sets 
train_inputs = inputs[trainIdx, :]
val_inputs   = inputs[valIdx, :]
test_inputs  = inputs[testIdx, :]

train_targets = targets_oh[trainIdx, :]
val_targets   = targets_oh[valIdx, :]
test_targets  = targets_oh[testIdx, :]

println("Train set: inputs $(size(train_inputs)), targets $(size(train_targets))")
println("Validation set: inputs $(size(val_inputs)), targets $(size(val_targets))")
println("Test set: inputs $(size(test_inputs)), targets $(size(test_targets))")


"""
3. Calculate the parameter values corresponding to the type of normalisation to be used with your data (maximum/minimum or mean/standard deviation for each attribute) from the training set only.
  * This part does not ask to normalise the training set, but to calculate the normalisation values from the training set. 
"""
min_vals, max_vals  = calculateMinMaxNormalizationParameters(inputs);

print("minimum : $min_vals \n size : $(size(min_vals)) \n");
print("maximum : $max_vals \n size : $(size(max_vals)) \n");


"""
4. With these parameters for normalisation calculated in the previous step, normalise training, validation and test sets.
5. Train different architectures, and, for each one of them, draw graphs of the evolution of the training, validation and test loss values in the same graph, including cycle 0. 
"""
# -4. Normalize datasets ---
println("Before normalization:")
println("Train set: inputs $(size(train_inputs)), targets $(size(train_targets))")
println("Validation set: inputs $(size(val_inputs)), targets $(size(val_targets))")
println("Test set: inputs $(size(test_inputs)), targets $(size(test_targets))")

# -4.1 Calculate normalization parameters only from training set ---
min_vals, max_vals = calculateMinMaxNormalizationParameters(train_inputs)

# -4.2 Apply normalization to all sets (using training set parameters) ---
train_inputs = normalizeMinMax!(train_inputs, (min_vals, max_vals))
val_inputs   = normalizeMinMax!(val_inputs, (min_vals, max_vals))
test_inputs  = normalizeMinMax!(test_inputs, (min_vals, max_vals))

println("\nAfter normalization:")

# ✅ Check  training,validation and test inputs
# ✅ Training set must map exactly to [0,1]
# ✅ We expects all normalized values to stay within [0,1], we  clip them

val_inputs  = clamp.(val_inputs, 0.0, 1.0)
test_inputs = clamp.(test_inputs, 0.0, 1.0)



# Convert to float32 for Flux compatibility


train_inputs = Float32.(train_inputs)
val_inputs = Float32.(val_inputs)
test_inputs = Float32.(test_inputs)



@assert(all(minimum(train_inputs, dims=1) .== 0))
@assert(all(maximum(train_inputs, dims=1) .== 1))

# ✅ Validation/Test should only fall within [0,1]
@assert(all(minimum(val_inputs, dims=1) .>= 0))
@assert(all(maximum(val_inputs, dims=1) .<= 1))
@assert(all(minimum(test_inputs, dims=1) .>= 0))
@assert(all(maximum(test_inputs, dims=1) .<= 1))



println("Train inputs range per feature: ", (minimum(train_inputs, dims=1), maximum(train_inputs, dims=1)))
println("Validation inputs range per feature: ", (minimum(val_inputs, dims=1), maximum(val_inputs, dims=1)))
println("Test inputs range per feature: ", (minimum(test_inputs, dims=1), maximum(test_inputs, dims=1)))
# Out:
# idx indices: [85, 123, 78, 27, 76, 32, 96, 89, 133, 9, 128, 113, 142, 51, 143, 20, 67, 83, 5, 77, 44, 24, 147, 130, 136, 57, 141, 12, 129, 138, 63, 144, 121, 86, 75, 116, 37, 45, 101, 19, 25, 33, 35, 49, 28, 53, 11, 100, 21, 99, 84, 66, 16, 92, 59, 104, 122, 145, 107, 26, 38, 120, 82, 125, 64, 91, 137, 148, 106, 58, 48, 30, 42, 108, 105, 150, 69, 131, 149, 80, 18, 46, 60, 65, 81, 114, 71, 3, 17, 40, 36, 29, 6, 79, 54, 134, 118, 115, 88, 34, 111, 74, 127, 98, 41, 93, 43, 70, 39, 72, 55, 124, 15, 102, 87, 4, 62, 135, 139, 117, 119, 73, 97, 109, 52, 10, 22, 50, 140, 68, 90, 126, 95, 23, 103, 112, 47, 14, 61, 56, 146, 7, 2, 13, 110, 94, 31, 8, 132, 1]
# idx indices: [9, 81, 17, 63, 60, 55, 8, 79, 80, 87, 50, 41, 75, 27, 52, 2, 89, 38, 5, 59, 105, 33, 72, 62, 30, 34, 100, 44, 48, 7, 11, 29, 19, 51, 39, 42, 65, 1, 88, 98, 93, 18, 57, 95, 69, 82, 16, 71, 22, 32, 25, 49, 66, 103, 12, 45, 64, 35, 24, 26, 36, 77, 40, 102, 67, 14, 92, 96, 3, 56, 83, 21, 58, 76, 94, 53, 61, 86, 104, 54, 13, 46, 99, 70, 28, 84, 37, 85, 101, 68, 43, 91, 23, 78, 31, 74, 90, 15, 73, 6, 20, 4, 47, 10, 97]
# Train indices: 60
# Validation indices: 45
# Test indices: 45
# Dataset size: (150, 5)
# targets
#  Any["Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-setosa", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-versicolor", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica", "Iris-virginica"]
#  size(150,)
# classes
#  Any["Iris-setosa", "Iris-versicolor", "Iris-virginica"]
#  num classes : 3
# One-hot encoded targets size: (150, 3)
# Train set: inputs (60, 4), targets (60, 3)
# Validation set: inputs (45, 4), targets (45, 3)
# Test set: inputs (45, 4), targets (45, 3)
# minimum : Float32[4.3 2.0 1.0 0.1]
#  size : (1, 4)
# maximum : Float32[7.9 4.4 6.9 2.5]
#  size : (1, 4)
# Before normalization:
# Train set: inputs (60, 4), targets (60, 3)
# Validation set: inputs (45, 4), targets (45, 3)
# Test set: inputs (45, 4), targets (45, 3)
#
# After normalization:
# Train inputs range per feature: (Float32[0.0 0.0 0.0 0.0], Float32[1.0 1.0 1.0 1.0])
# Validation inputs range per feature: (Float32[0.0 0.0 0.0 0.0], Float32[1.0 1.0 1.0 1.0])
# Test inputs range per feature: (Float32[0.0 0.0 0.0 0.0], Float32[1.0 0.9000001 1.0 1.0])

# %% [markdown]
# # Train and Plot

# %%
# We train mre architectures and store all results
# We will plot all losses one plot for each model
# --- List of architectures to try ---
architectures = [
    [10, 5],
    [4, 8, 2],
    [6, 12, 6, 2] ,
    [16, 8, 4],
    [8, 4, 2, 2],
    [20, 10, 5, 2] , 
    [5,3]  
]

# --- Store all results ---
results = Dict{String, Tuple{Vector{Float32}, Vector{Float32}, Vector{Float32}}}()


for topology in architectures
    println("\nTraining architecture: ", topology)
    finalAnn, trainLoss, valLoss, testLoss = trainClassANN(
        topology,
        (train_inputs, train_targets),
        validationDataset = (val_inputs, val_targets),
        testDataset = (test_inputs, test_targets),
        maxEpochs = 250,
        learningRate = 0.01,
        showText = true
    )
    results[string(topology)] = (trainLoss, valLoss, testLoss)
end
# results = [(topology1, (trainLoss1, valLoss1, testLoss1)), 
#            (topology2, (trainLoss2, valLoss2, testLoss2)), ...]



# --- Plotting all losses one plot for each model---
for (topology, (trainLoss, valLoss, testLoss)) in results
    epochs = 0:length(trainLoss)-1  # include cycle 0

    p = plot(epochs, trainLoss, label="Train Loss", lw=2, marker=:circle)
    
    if !isempty(valLoss)
        plot!(p, epochs, valLoss, label="Validation Loss", lw=2, linestyle=:dash, marker=:diamond)
    end
    
    if !isempty(testLoss)
        plot!(p, epochs, testLoss, label="Test Loss", lw=2, linestyle=:dot, marker=:star)
    end

    xlabel!("Epoch")
    ylabel!("Loss")
    title!("Loss Evolution - Topology: $(topology)")
    plot!(legend=:topright)
    
    display(p)  # show the plot
end
# Out:
# Training architecture: [10, 5]
# Epoch 0 - loss: 1.1836 - val_loss: 1.2047 - test_loss: 1.2291
# Epoch 1 - loss: 1.1632 - acc: 0.35 - val_loss: 1.1823 - val_acc: 0.3333 - test_loss: 1.2044 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 2 - loss: 1.147 - acc: 0.35 - val_loss: 1.1642 - val_acc: 0.3333 - test_loss: 1.184 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 3 - loss: 1.1343 - acc: 0.35 - val_loss: 1.1496 - val_acc: 0.3333 - test_loss: 1.1672 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 4 - loss: 1.1238 - acc: 0.35 - val_loss: 1.1374 - val_acc: 0.3333 - test_loss: 1.1528 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 5 - loss: 1.1146 - acc: 0.35 - val_loss: 1.1265 - val_acc: 0.3333 - test_loss: 1.1398 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 6 - loss: 1.1064 - acc: 0.35 - val_loss: 1.1167 - val_acc: 0.3333 - test_loss: 1.1281 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 7 - loss: 1.0994 - acc: 0.35 - val_loss: 1.1082 - val_acc: 0.3333 - test_loss: 1.1177 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 8 - loss: 1.0937 - acc: 0.35 - val_loss: 1.1012 - val_acc: 0.3333 - test_loss: 1.1089 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 9 - loss: 1.0894 - acc: 0.35 - val_loss: 1.0956 - val_acc: 0.3333 - test_loss: 1.1016 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 10 - loss: 1.0864 - acc: 0.35 - val_loss: 1.0914 - val_acc: 0.3333 - test_loss: 1.0959 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 11 - loss: 1.0846 - acc: 0.35 - val_loss: 1.0884 - val_acc: 0.3333 - test_loss: 1.0916 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 12 - loss: 1.0836 - acc: 0.35 - val_loss: 1.0864 - val_acc: 0.3333 - test_loss: 1.0883 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 13 - loss: 1.0831 - acc: 0.35 - val_loss: 1.085 - val_acc: 0.3333 - test_loss: 1.0857 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 14 - loss: 1.0829 - acc: 0.3667 - val_loss: 1.084 - val_acc: 0.3333 - test_loss: 1.0837 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 15 - loss: 1.0826 - acc: 0.6667 - val_loss: 1.083 - val_acc: 0.6667 - test_loss: 1.0818 - test_acc: 0.6667 - test_error: 0.3333 - epochsWithoutImprovement 0
# Epoch 16 - loss: 1.0823 - acc: 0.65 - val_loss: 1.0821 - val_acc: 0.6667 - test_loss: 1.0801 - test_acc: 0.6667 - test_error: 0.3333 - epochsWithoutImprovement 0
# Epoch 17 - loss: 1.0818 - acc: 0.4 - val_loss: 1.0811 - val_acc: 0.4222 - test_loss: 1.0785 - test_acc: 0.4222 - test_error: 0.5778 - epochsWithoutImprovement 0
# Epoch 18 - loss: 1.081 - acc: 0.3167 - val_loss: 1.0799 - val_acc: 0.3333 - test_loss: 1.0769 - test_acc: 0.3778 - test_error: 0.6222 - epochsWithoutImprovement 0
# Epoch 19 - loss: 1.0801 - acc: 0.3167 - val_loss: 1.0787 - val_acc: 0.3333 - test_loss: 1.0753 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 20 - loss: 1.079 - acc: 0.3167 - val_loss: 1.0774 - val_acc: 0.3556 - test_loss: 1.0738 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 21 - loss: 1.0776 - acc: 0.35 - val_loss: 1.076 - val_acc: 0.4444 - test_loss: 1.0722 - test_acc: 0.4444 - test_error: 0.5556 - epochsWithoutImprovement 0
# Epoch 22 - loss: 1.0761 - acc: 0.5833 - val_loss: 1.0744 - val_acc: 0.6444 - test_loss: 1.0707 - test_acc: 0.6667 - test_error: 0.3333 - epochsWithoutImprovement 0
# Epoch 23 - loss: 1.0743 - acc: 0.65 - val_loss: 1.0727 - val_acc: 0.6667 - test_loss: 1.0691 - test_acc: 0.6889 - test_error: 0.3111 - epochsWithoutImprovement 0
# Epoch 24 - loss: 1.0723 - acc: 0.65 - val_loss: 1.0709 - val_acc: 0.6444 - test_loss: 1.0674 - test_acc: 0.6889 - test_error: 0.3111 - epochsWithoutImprovement 0
# Epoch 25 - loss: 1.07 - acc: 0.65 - val_loss: 1.0689 - val_acc: 0.6444 - test_loss: 1.0656 - test_acc: 0.6889 - test_error: 0.3111 - epochsWithoutImprovement 0
# Epoch 26 - loss: 1.0676 - acc: 0.65 - val_loss: 1.0667 - val_acc: 0.6444 - test_loss: 1.0638 - test_acc: 0.6889 - test_error: 0.3111 - epochsWithoutImprovement 0
# Epoch 27 - loss: 1.065 - acc: 0.65 - val_loss: 1.0645 - val_acc: 0.6667 - test_loss: 1.062 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 28 - loss: 1.0624 - acc: 0.65 - val_loss: 1.0623 - val_acc: 0.6667 - test_loss: 1.0601 - test_acc: 0.7333 - test_error: 0.2667 - epochsWithoutImprovement 0
# Epoch 29 - loss: 1.0598 - acc: 0.7667 - val_loss: 1.0601 - val_acc: 0.7556 - test_loss: 1.0583 - test_acc: 0.8 - test_error: 0.2 - epochsWithoutImprovement 0
# Epoch 30 - loss: 1.0572 - acc: 0.7167 - val_loss: 1.0579 - val_acc: 0.7333 - test_loss: 1.0565 - test_acc: 0.8 - test_error: 0.2 - epochsWithoutImprovement 0
# Epoch 31 - loss: 1.0546 - acc: 0.65 - val_loss: 1.0556 - val_acc: 0.6889 - test_loss: 1.0546 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 32 - loss: 1.052 - acc: 0.5167 - val_loss: 1.0534 - val_acc: 0.3556 - test_loss: 1.0527 - test_acc: 0.5333 - test_error: 0.4667 - epochsWithoutImprovement 0
# Epoch 33 - loss: 1.0493 - acc: 0.3833 - val_loss: 1.051 - val_acc: 0.3333 - test_loss: 1.0506 - test_acc: 0.3333 - test_error: 0.6667 - epochsWithoutImprovement 0
# Epoch 34 - loss: 1.0465 - acc: 0.3667 - val_loss: 1.0486 - val_acc: 0.3333 - test_loss: 1.0484 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 35 - loss: 1.0436 - acc: 0.35 - val_loss: 1.0459 - val_acc: 0.3333 - test_loss: 1.046 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 36 - loss: 1.0405 - acc: 0.35 - val_loss: 1.0431 - val_acc: 0.3333 - test_loss: 1.0432 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 37 - loss: 1.0372 - acc: 0.35 - val_loss: 1.04 - val_acc: 0.3333 - test_loss: 1.0402 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 38 - loss: 1.0337 - acc: 0.35 - val_loss: 1.0366 - val_acc: 0.3333 - test_loss: 1.0368 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 39 - loss: 1.0299 - acc: 0.35 - val_loss: 1.0329 - val_acc: 0.3333 - test_loss: 1.0331 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 40 - loss: 1.0259 - acc: 0.35 - val_loss: 1.029 - val_acc: 0.3333 - test_loss: 1.0289 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 41 - loss: 1.0216 - acc: 0.3667 - val_loss: 1.0247 - val_acc: 0.3333 - test_loss: 1.0244 - test_acc: 0.3333 - test_error: 0.6667 - epochsWithoutImprovement 0
# Epoch 42 - loss: 1.0169 - acc: 0.3833 - val_loss: 1.02 - val_acc: 0.3333 - test_loss: 1.0195 - test_acc: 0.3333 - test_error: 0.6667 - epochsWithoutImprovement 0
# Epoch 43 - loss: 1.0119 - acc: 0.45 - val_loss: 1.015 - val_acc: 0.3556 - test_loss: 1.0141 - test_acc: 0.4222 - test_error: 0.5778 - epochsWithoutImprovement 0
# Epoch 44 - loss: 1.0066 - acc: 0.5667 - val_loss: 1.0096 - val_acc: 0.4444 - test_loss: 1.0083 - test_acc: 0.6222 - test_error: 0.3778 - epochsWithoutImprovement 0
# Epoch 45 - loss: 1.0009 - acc: 0.5833 - val_loss: 1.0037 - val_acc: 0.6222 - test_loss: 1.0021 - test_acc: 0.6889 - test_error: 0.3111 - epochsWithoutImprovement 0
# Epoch 46 - loss: 0.9949 - acc: 0.65 - val_loss: 0.9975 - val_acc: 0.6667 - test_loss: 0.9954 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 47 - loss: 0.9884 - acc: 0.6667 - val_loss: 0.991 - val_acc: 0.6889 - test_loss: 0.9883 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 48 - loss: 0.9817 - acc: 0.6667 - val_loss: 0.984 - val_acc: 0.6889 - test_loss: 0.9809 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 49 - loss: 0.9745 - acc: 0.6667 - val_loss: 0.9767 - val_acc: 0.7111 - test_loss: 0.973 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 50 - loss: 0.967 - acc: 0.6667 - val_loss: 0.969 - val_acc: 0.7111 - test_loss: 0.9647 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 51 - loss: 0.959 - acc: 0.6667 - val_loss: 0.9608 - val_acc: 0.7111 - test_loss: 0.9561 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 52 - loss: 0.9507 - acc: 0.65 - val_loss: 0.9524 - val_acc: 0.7333 - test_loss: 0.947 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 53 - loss: 0.9419 - acc: 0.6667 - val_loss: 0.9435 - val_acc: 0.7778 - test_loss: 0.9375 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 54 - loss: 0.9327 - acc: 0.6667 - val_loss: 0.9342 - val_acc: 0.7778 - test_loss: 0.9276 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 55 - loss: 0.923 - acc: 0.6833 - val_loss: 0.9245 - val_acc: 0.7556 - test_loss: 0.9172 - test_acc: 0.7556 - test_error: 0.2444 - epochsWithoutImprovement 0
# Epoch 56 - loss: 0.9129 - acc: 0.7 - val_loss: 0.9145 - val_acc: 0.7556 - test_loss: 0.9065 - test_acc: 0.7556 - test_error: 0.2444 - epochsWithoutImprovement 0
# Epoch 57 - loss: 0.9024 - acc: 0.7167 - val_loss: 0.904 - val_acc: 0.7778 - test_loss: 0.8954 - test_acc: 0.7778 - test_error: 0.2222 - epochsWithoutImprovement 0
# Epoch 58 - loss: 0.8915 - acc: 0.7167 - val_loss: 0.8932 - val_acc: 0.7778 - test_loss: 0.8838 - test_acc: 0.8 - test_error: 0.2 - epochsWithoutImprovement 0
# Epoch 59 - loss: 0.8801 - acc: 0.7167 - val_loss: 0.882 - val_acc: 0.7778 - test_loss: 0.8719 - test_acc: 0.8 - test_error: 0.2 - epochsWithoutImprovement 0
# Epoch 60 - loss: 0.8683 - acc: 0.7333 - val_loss: 0.8705 - val_acc: 0.7778 - test_loss: 0.8596 - test_acc: 0.8222 - test_error: 0.1778 - epochsWithoutImprovement 0
# Epoch 61 - loss: 0.8562 - acc: 0.7333 - val_loss: 0.8586 - val_acc: 0.8 - test_loss: 0.8469 - test_acc: 0.8222 - test_error: 0.1778 - epochsWithoutImprovement 0
# Epoch 62 - loss: 0.8436 - acc: 0.7333 - val_loss: 0.8464 - val_acc: 0.8 - test_loss: 0.8339 - test_acc: 0.8222 - test_error: 0.1778 - epochsWithoutImprovement 0
# Epoch 63 - loss: 0.8308 - acc: 0.7167 - val_loss: 0.8339 - val_acc: 0.8 - test_loss: 0.8206 - test_acc: 0.8222 - test_error: 0.1778 - epochsWithoutImprovement 0
# Epoch 64 - loss: 0.8177 - acc: 0.7333 - val_loss: 0.8211 - val_acc: 0.7556 - test_loss: 0.807 - test_acc: 0.8 - test_error: 0.2 - epochsWithoutImprovement 0
# Epoch 65 - loss: 0.8043 - acc: 0.7333 - val_loss: 0.8081 - val_acc: 0.7556 - test_loss: 0.7931 - test_acc: 0.8 - test_error: 0.2 - epochsWithoutImprovement 0
# Epoch 66 - loss: 0.7906 - acc: 0.7333 - val_loss: 0.7948 - val_acc: 0.7556 - test_loss: 0.7789 - test_acc: 0.7778 - test_error: 0.2222 - epochsWithoutImprovement 0
# Epoch 67 - loss: 0.7769 - acc: 0.7333 - val_loss: 0.7814 - val_acc: 0.7556 - test_loss: 0.7646 - test_acc: 0.7778 - test_error: 0.2222 - epochsWithoutImprovement 0
# Epoch 68 - loss: 0.7629 - acc: 0.7333 - val_loss: 0.7679 - val_acc: 0.7556 - test_loss: 0.7501 - test_acc: 0.7778 - test_error: 0.2222 - epochsWithoutImprovement 0
# Epoch 69 - loss: 0.7489 - acc: 0.7333 - val_loss: 0.7543 - val_acc: 0.7778 - test_loss: 0.7356 - test_acc: 0.7778 - test_error: 0.2222 - epochsWithoutImprovement 0
# Epoch 70 - loss: 0.7349 - acc: 0.75 - val_loss: 0.7406 - val_acc: 0.7778 - test_loss: 0.7209 - test_acc: 0.8 - test_error: 0.2 - epochsWithoutImprovement 0
# Epoch 71 - loss: 0.7208 - acc: 0.7667 - val_loss: 0.7269 - val_acc: 0.7778 - test_loss: 0.7063 - test_acc: 0.8222 - test_error: 0.1778 - epochsWithoutImprovement 0
# Epoch 72 - loss: 0.7069 - acc: 0.8 - val_loss: 0.7134 - val_acc: 0.7778 - test_loss: 0.6918 - test_acc: 0.8444 - test_error: 0.1556 - epochsWithoutImprovement 0
# Epoch 73 - loss: 0.6931 - acc: 0.8167 - val_loss: 0.6999 - val_acc: 0.7778 - test_loss: 0.6774 - test_acc: 0.8444 - test_error: 0.1556 - epochsWithoutImprovement 0
# Epoch 74 - loss: 0.6794 - acc: 0.8167 - val_loss: 0.6867 - val_acc: 0.7778 - test_loss: 0.6631 - test_acc: 0.8667 - test_error: 0.1333 - epochsWithoutImprovement 0
# Epoch 75 - loss: 0.6659 - acc: 0.8333 - val_loss: 0.6736 - val_acc: 0.7778 - test_loss: 0.6492 - test_acc: 0.8667 - test_error: 0.1333 - epochsWithoutImprovement 0
# Epoch 76 - loss: 0.6528 - acc: 0.8333 - val_loss: 0.6609 - val_acc: 0.7778 - test_loss: 0.6355 - test_acc: 0.8889 - test_error: 0.1111 - epochsWithoutImprovement 0
# Epoch 77 - loss: 0.6399 - acc: 0.8333 - val_loss: 0.6484 - val_acc: 0.7778 - test_loss: 0.6221 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 78 - loss: 0.6273 - acc: 0.8333 - val_loss: 0.6363 - val_acc: 0.7778 - test_loss: 0.6091 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 79 - loss: 0.6151 - acc: 0.85 - val_loss: 0.6246 - val_acc: 0.8 - test_loss: 0.5965 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 80 - loss: 0.6032 - acc: 0.85 - val_loss: 0.6133 - val_acc: 0.8222 - test_loss: 0.5843 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 81 - loss: 0.5917 - acc: 0.85 - val_loss: 0.6025 - val_acc: 0.8222 - test_loss: 0.5726 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 82 - loss: 0.5806 - acc: 0.85 - val_loss: 0.592 - val_acc: 0.8444 - test_loss: 0.5612 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 83 - loss: 0.5699 - acc: 0.85 - val_loss: 0.5819 - val_acc: 0.8444 - test_loss: 0.5503 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 84 - loss: 0.5595 - acc: 0.85 - val_loss: 0.5723 - val_acc: 0.8444 - test_loss: 0.5398 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 85 - loss: 0.5495 - acc: 0.85 - val_loss: 0.563 - val_acc: 0.8667 - test_loss: 0.5296 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 86 - loss: 0.5398 - acc: 0.8667 - val_loss: 0.5541 - val_acc: 0.8667 - test_loss: 0.5198 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 87 - loss: 0.5305 - acc: 0.8667 - val_loss: 0.5456 - val_acc: 0.8667 - test_loss: 0.5104 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 88 - loss: 0.5215 - acc: 0.8833 - val_loss: 0.5374 - val_acc: 0.8667 - test_loss: 0.5013 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 89 - loss: 0.5127 - acc: 0.9 - val_loss: 0.5294 - val_acc: 0.8667 - test_loss: 0.4925 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 90 - loss: 0.5043 - acc: 0.9167 - val_loss: 0.5218 - val_acc: 0.8667 - test_loss: 0.484 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 91 - loss: 0.4961 - acc: 0.9167 - val_loss: 0.5145 - val_acc: 0.8667 - test_loss: 0.4757 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 92 - loss: 0.4881 - acc: 0.9167 - val_loss: 0.5074 - val_acc: 0.8667 - test_loss: 0.4677 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 93 - loss: 0.4803 - acc: 0.9167 - val_loss: 0.5005 - val_acc: 0.8667 - test_loss: 0.4599 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 94 - loss: 0.4728 - acc: 0.9333 - val_loss: 0.4939 - val_acc: 0.8667 - test_loss: 0.4524 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 95 - loss: 0.4654 - acc: 0.95 - val_loss: 0.4875 - val_acc: 0.8667 - test_loss: 0.445 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 96 - loss: 0.4582 - acc: 0.95 - val_loss: 0.4812 - val_acc: 0.8667 - test_loss: 0.4378 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 97 - loss: 0.4511 - acc: 0.95 - val_loss: 0.4752 - val_acc: 0.8667 - test_loss: 0.4308 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 98 - loss: 0.4441 - acc: 0.95 - val_loss: 0.4693 - val_acc: 0.8667 - test_loss: 0.424 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 99 - loss: 0.4373 - acc: 0.95 - val_loss: 0.4636 - val_acc: 0.8667 - test_loss: 0.4173 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 100 - loss: 0.4306 - acc: 0.95 - val_loss: 0.458 - val_acc: 0.8667 - test_loss: 0.4107 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 101 - loss: 0.424 - acc: 0.9667 - val_loss: 0.4526 - val_acc: 0.8667 - test_loss: 0.4043 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 102 - loss: 0.4175 - acc: 0.9667 - val_loss: 0.4473 - val_acc: 0.8667 - test_loss: 0.3979 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 103 - loss: 0.4111 - acc: 0.9667 - val_loss: 0.442 - val_acc: 0.8667 - test_loss: 0.3917 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 104 - loss: 0.4048 - acc: 0.9667 - val_loss: 0.4369 - val_acc: 0.8667 - test_loss: 0.3856 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 105 - loss: 0.3986 - acc: 0.9667 - val_loss: 0.4319 - val_acc: 0.8667 - test_loss: 0.3796 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 106 - loss: 0.3925 - acc: 0.9667 - val_loss: 0.427 - val_acc: 0.8667 - test_loss: 0.3737 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 107 - loss: 0.3864 - acc: 0.9667 - val_loss: 0.4222 - val_acc: 0.8667 - test_loss: 0.3678 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 108 - loss: 0.3804 - acc: 0.9667 - val_loss: 0.4175 - val_acc: 0.8667 - test_loss: 0.3621 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 109 - loss: 0.3745 - acc: 0.9667 - val_loss: 0.4129 - val_acc: 0.8667 - test_loss: 0.3565 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 110 - loss: 0.3687 - acc: 0.9667 - val_loss: 0.4083 - val_acc: 0.8667 - test_loss: 0.3509 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 111 - loss: 0.3629 - acc: 0.9667 - val_loss: 0.4039 - val_acc: 0.8667 - test_loss: 0.3455 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 112 - loss: 0.3572 - acc: 0.9667 - val_loss: 0.3995 - val_acc: 0.8667 - test_loss: 0.3401 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 113 - loss: 0.3516 - acc: 0.9667 - val_loss: 0.3952 - val_acc: 0.8667 - test_loss: 0.3349 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 114 - loss: 0.3461 - acc: 0.9667 - val_loss: 0.391 - val_acc: 0.8889 - test_loss: 0.3297 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 115 - loss: 0.3406 - acc: 0.9667 - val_loss: 0.3868 - val_acc: 0.8889 - test_loss: 0.3246 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 116 - loss: 0.3352 - acc: 0.9667 - val_loss: 0.3827 - val_acc: 0.8889 - test_loss: 0.3196 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 117 - loss: 0.3299 - acc: 0.9667 - val_loss: 0.3787 - val_acc: 0.8889 - test_loss: 0.3146 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 118 - loss: 0.3246 - acc: 0.9667 - val_loss: 0.3747 - val_acc: 0.8889 - test_loss: 0.3098 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 119 - loss: 0.3194 - acc: 0.9667 - val_loss: 0.3707 - val_acc: 0.8889 - test_loss: 0.305 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 120 - loss: 0.3143 - acc: 0.9667 - val_loss: 0.3668 - val_acc: 0.8889 - test_loss: 0.3003 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 121 - loss: 0.3093 - acc: 0.9667 - val_loss: 0.363 - val_acc: 0.8889 - test_loss: 0.2957 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 122 - loss: 0.3044 - acc: 0.9667 - val_loss: 0.3593 - val_acc: 0.8889 - test_loss: 0.2912 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 123 - loss: 0.2995 - acc: 0.9667 - val_loss: 0.3556 - val_acc: 0.8889 - test_loss: 0.2867 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 124 - loss: 0.2947 - acc: 0.9667 - val_loss: 0.3519 - val_acc: 0.8889 - test_loss: 0.2824 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 125 - loss: 0.29 - acc: 0.9667 - val_loss: 0.3483 - val_acc: 0.8889 - test_loss: 0.2781 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 126 - loss: 0.2853 - acc: 0.9667 - val_loss: 0.3448 - val_acc: 0.8889 - test_loss: 0.2739 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 127 - loss: 0.2807 - acc: 0.9667 - val_loss: 0.3413 - val_acc: 0.8889 - test_loss: 0.2698 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 128 - loss: 0.2762 - acc: 0.9667 - val_loss: 0.3378 - val_acc: 0.8889 - test_loss: 0.2658 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 129 - loss: 0.2718 - acc: 0.9667 - val_loss: 0.3344 - val_acc: 0.8889 - test_loss: 0.2619 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 130 - loss: 0.2675 - acc: 0.9667 - val_loss: 0.3311 - val_acc: 0.8889 - test_loss: 0.258 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 131 - loss: 0.2632 - acc: 0.9667 - val_loss: 0.3278 - val_acc: 0.8889 - test_loss: 0.2542 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 132 - loss: 0.259 - acc: 0.9667 - val_loss: 0.3245 - val_acc: 0.8889 - test_loss: 0.2505 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 133 - loss: 0.2549 - acc: 0.9667 - val_loss: 0.3213 - val_acc: 0.8889 - test_loss: 0.2469 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 134 - loss: 0.2509 - acc: 0.9667 - val_loss: 0.3182 - val_acc: 0.8889 - test_loss: 0.2433 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 135 - loss: 0.2469 - acc: 0.9667 - val_loss: 0.315 - val_acc: 0.8889 - test_loss: 0.2398 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 136 - loss: 0.243 - acc: 0.9667 - val_loss: 0.312 - val_acc: 0.8889 - test_loss: 0.2364 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 137 - loss: 0.2392 - acc: 0.9667 - val_loss: 0.309 - val_acc: 0.8889 - test_loss: 0.2331 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 138 - loss: 0.2355 - acc: 0.9667 - val_loss: 0.306 - val_acc: 0.8889 - test_loss: 0.2298 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 139 - loss: 0.2318 - acc: 0.9667 - val_loss: 0.3031 - val_acc: 0.8889 - test_loss: 0.2267 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 140 - loss: 0.2282 - acc: 0.9667 - val_loss: 0.3002 - val_acc: 0.8889 - test_loss: 0.2236 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 141 - loss: 0.2246 - acc: 0.9667 - val_loss: 0.2973 - val_acc: 0.8889 - test_loss: 0.2205 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 142 - loss: 0.2212 - acc: 0.9667 - val_loss: 0.2945 - val_acc: 0.8889 - test_loss: 0.2175 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 143 - loss: 0.2178 - acc: 0.9667 - val_loss: 0.2918 - val_acc: 0.8889 - test_loss: 0.2146 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 144 - loss: 0.2144 - acc: 0.9667 - val_loss: 0.2891 - val_acc: 0.8889 - test_loss: 0.2118 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 145 - loss: 0.2112 - acc: 0.9667 - val_loss: 0.2864 - val_acc: 0.8889 - test_loss: 0.209 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 146 - loss: 0.208 - acc: 0.9667 - val_loss: 0.2837 - val_acc: 0.8889 - test_loss: 0.2063 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 147 - loss: 0.2048 - acc: 0.9667 - val_loss: 0.2812 - val_acc: 0.8889 - test_loss: 0.2037 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 148 - loss: 0.2018 - acc: 0.9667 - val_loss: 0.2786 - val_acc: 0.8889 - test_loss: 0.2011 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 149 - loss: 0.1988 - acc: 0.9667 - val_loss: 0.2761 - val_acc: 0.8889 - test_loss: 0.1986 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 150 - loss: 0.1958 - acc: 0.9667 - val_loss: 0.2736 - val_acc: 0.8889 - test_loss: 0.1961 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 151 - loss: 0.1929 - acc: 0.9667 - val_loss: 0.2712 - val_acc: 0.9111 - test_loss: 0.1937 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 152 - loss: 0.1901 - acc: 0.9667 - val_loss: 0.2688 - val_acc: 0.9111 - test_loss: 0.1913 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 153 - loss: 0.1873 - acc: 0.9667 - val_loss: 0.2664 - val_acc: 0.9111 - test_loss: 0.189 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 154 - loss: 0.1846 - acc: 0.9667 - val_loss: 0.2641 - val_acc: 0.9111 - test_loss: 0.1868 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 155 - loss: 0.182 - acc: 0.9667 - val_loss: 0.2618 - val_acc: 0.9111 - test_loss: 0.1846 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 156 - loss: 0.1794 - acc: 0.9667 - val_loss: 0.2595 - val_acc: 0.9111 - test_loss: 0.1824 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 157 - loss: 0.1768 - acc: 0.9667 - val_loss: 0.2573 - val_acc: 0.9111 - test_loss: 0.1803 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 158 - loss: 0.1743 - acc: 0.9667 - val_loss: 0.2551 - val_acc: 0.9111 - test_loss: 0.1783 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 159 - loss: 0.1719 - acc: 0.9667 - val_loss: 0.2529 - val_acc: 0.9111 - test_loss: 0.1763 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 160 - loss: 0.1695 - acc: 0.9667 - val_loss: 0.2508 - val_acc: 0.9111 - test_loss: 0.1743 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 161 - loss: 0.1672 - acc: 0.9667 - val_loss: 0.2487 - val_acc: 0.9111 - test_loss: 0.1724 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 162 - loss: 0.1649 - acc: 0.9667 - val_loss: 0.2466 - val_acc: 0.9111 - test_loss: 0.1705 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 163 - loss: 0.1627 - acc: 0.9667 - val_loss: 0.2446 - val_acc: 0.9111 - test_loss: 0.1687 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 164 - loss: 0.1605 - acc: 0.9667 - val_loss: 0.2426 - val_acc: 0.9111 - test_loss: 0.1669 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 165 - loss: 0.1584 - acc: 0.9667 - val_loss: 0.2406 - val_acc: 0.9111 - test_loss: 0.1651 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 166 - loss: 0.1563 - acc: 0.9667 - val_loss: 0.2386 - val_acc: 0.9111 - test_loss: 0.1634 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 167 - loss: 0.1542 - acc: 0.9667 - val_loss: 0.2367 - val_acc: 0.9111 - test_loss: 0.1617 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 168 - loss: 0.1523 - acc: 0.9667 - val_loss: 0.2348 - val_acc: 0.9111 - test_loss: 0.1601 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 169 - loss: 0.1503 - acc: 0.9667 - val_loss: 0.2329 - val_acc: 0.9111 - test_loss: 0.1585 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 170 - loss: 0.1484 - acc: 0.9667 - val_loss: 0.2311 - val_acc: 0.9111 - test_loss: 0.1569 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 171 - loss: 0.1466 - acc: 0.9667 - val_loss: 0.2292 - val_acc: 0.9111 - test_loss: 0.1554 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 172 - loss: 0.1447 - acc: 0.9667 - val_loss: 0.2274 - val_acc: 0.9111 - test_loss: 0.1539 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 173 - loss: 0.143 - acc: 0.9667 - val_loss: 0.2257 - val_acc: 0.9111 - test_loss: 0.1524 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 174 - loss: 0.1413 - acc: 0.9667 - val_loss: 0.2239 - val_acc: 0.9111 - test_loss: 0.151 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 175 - loss: 0.1396 - acc: 0.9667 - val_loss: 0.2222 - val_acc: 0.9111 - test_loss: 0.1496 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 176 - loss: 0.1379 - acc: 0.9667 - val_loss: 0.2205 - val_acc: 0.9111 - test_loss: 0.1482 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 177 - loss: 0.1363 - acc: 0.9667 - val_loss: 0.2188 - val_acc: 0.9111 - test_loss: 0.1468 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 178 - loss: 0.1347 - acc: 0.9667 - val_loss: 0.2172 - val_acc: 0.9111 - test_loss: 0.1455 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 179 - loss: 0.1332 - acc: 0.9667 - val_loss: 0.2155 - val_acc: 0.9111 - test_loss: 0.1442 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 180 - loss: 0.1317 - acc: 0.9667 - val_loss: 0.2139 - val_acc: 0.9333 - test_loss: 0.1429 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 181 - loss: 0.1303 - acc: 0.9667 - val_loss: 0.2124 - val_acc: 0.9333 - test_loss: 0.1417 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 182 - loss: 0.1288 - acc: 0.9667 - val_loss: 0.2108 - val_acc: 0.9333 - test_loss: 0.1405 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 183 - loss: 0.1274 - acc: 0.9833 - val_loss: 0.2093 - val_acc: 0.9333 - test_loss: 0.1393 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 184 - loss: 0.1261 - acc: 0.9833 - val_loss: 0.2078 - val_acc: 0.9333 - test_loss: 0.1381 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 185 - loss: 0.1248 - acc: 0.9833 - val_loss: 0.2063 - val_acc: 0.9333 - test_loss: 0.137 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 186 - loss: 0.1235 - acc: 0.9833 - val_loss: 0.2048 - val_acc: 0.9333 - test_loss: 0.1358 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 187 - loss: 0.1222 - acc: 0.9833 - val_loss: 0.2034 - val_acc: 0.9333 - test_loss: 0.1347 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 188 - loss: 0.121 - acc: 0.9833 - val_loss: 0.2019 - val_acc: 0.9333 - test_loss: 0.1337 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 189 - loss: 0.1198 - acc: 0.9833 - val_loss: 0.2005 - val_acc: 0.9333 - test_loss: 0.1326 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 190 - loss: 0.1186 - acc: 0.9833 - val_loss: 0.1991 - val_acc: 0.9333 - test_loss: 0.1316 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 191 - loss: 0.1175 - acc: 0.9833 - val_loss: 0.1978 - val_acc: 0.9333 - test_loss: 0.1305 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 192 - loss: 0.1163 - acc: 0.9833 - val_loss: 0.1964 - val_acc: 0.9333 - test_loss: 0.1295 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 193 - loss: 0.1153 - acc: 0.9833 - val_loss: 0.1951 - val_acc: 0.9333 - test_loss: 0.1286 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 194 - loss: 0.1142 - acc: 0.9833 - val_loss: 0.1938 - val_acc: 0.9333 - test_loss: 0.1276 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 195 - loss: 0.1131 - acc: 0.9833 - val_loss: 0.1925 - val_acc: 0.9333 - test_loss: 0.1267 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 196 - loss: 0.1121 - acc: 0.9833 - val_loss: 0.1913 - val_acc: 0.9333 - test_loss: 0.1257 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 197 - loss: 0.1111 - acc: 0.9833 - val_loss: 0.1901 - val_acc: 0.9333 - test_loss: 0.1248 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 198 - loss: 0.1102 - acc: 0.9833 - val_loss: 0.1888 - val_acc: 0.9333 - test_loss: 0.1239 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 199 - loss: 0.1092 - acc: 0.9833 - val_loss: 0.1876 - val_acc: 0.9333 - test_loss: 0.1231 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 200 - loss: 0.1083 - acc: 0.9833 - val_loss: 0.1865 - val_acc: 0.9333 - test_loss: 0.1222 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 201 - loss: 0.1074 - acc: 0.9833 - val_loss: 0.1853 - val_acc: 0.9333 - test_loss: 0.1214 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 202 - loss: 0.1065 - acc: 0.9833 - val_loss: 0.1841 - val_acc: 0.9333 - test_loss: 0.1205 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 203 - loss: 0.1057 - acc: 0.9833 - val_loss: 0.183 - val_acc: 0.9333 - test_loss: 0.1197 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 204 - loss: 0.1048 - acc: 0.9833 - val_loss: 0.1819 - val_acc: 0.9333 - test_loss: 0.1189 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 205 - loss: 0.104 - acc: 0.9833 - val_loss: 0.1808 - val_acc: 0.9333 - test_loss: 0.1181 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 206 - loss: 0.1032 - acc: 0.9833 - val_loss: 0.1797 - val_acc: 0.9333 - test_loss: 0.1174 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 207 - loss: 0.1024 - acc: 0.9833 - val_loss: 0.1787 - val_acc: 0.9333 - test_loss: 0.1166 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 208 - loss: 0.1016 - acc: 0.9833 - val_loss: 0.1776 - val_acc: 0.9333 - test_loss: 0.1158 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 209 - loss: 0.1009 - acc: 0.9833 - val_loss: 0.1766 - val_acc: 0.9333 - test_loss: 0.1151 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 210 - loss: 0.1001 - acc: 0.9833 - val_loss: 0.1756 - val_acc: 0.9333 - test_loss: 0.1144 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 211 - loss: 0.0994 - acc: 0.9833 - val_loss: 0.1746 - val_acc: 0.9333 - test_loss: 0.1137 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 212 - loss: 0.0987 - acc: 0.9833 - val_loss: 0.1737 - val_acc: 0.9333 - test_loss: 0.113 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 213 - loss: 0.098 - acc: 0.9833 - val_loss: 0.1727 - val_acc: 0.9333 - test_loss: 0.1123 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 214 - loss: 0.0973 - acc: 0.9833 - val_loss: 0.1717 - val_acc: 0.9333 - test_loss: 0.1116 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 215 - loss: 0.0967 - acc: 0.9833 - val_loss: 0.1708 - val_acc: 0.9333 - test_loss: 0.1109 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 216 - loss: 0.096 - acc: 0.9833 - val_loss: 0.1699 - val_acc: 0.9333 - test_loss: 0.1103 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 217 - loss: 0.0954 - acc: 0.9833 - val_loss: 0.169 - val_acc: 0.9333 - test_loss: 0.1096 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 218 - loss: 0.0948 - acc: 0.9833 - val_loss: 0.1681 - val_acc: 0.9333 - test_loss: 0.109 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 219 - loss: 0.0942 - acc: 0.9833 - val_loss: 0.1672 - val_acc: 0.9333 - test_loss: 0.1084 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 220 - loss: 0.0936 - acc: 0.9833 - val_loss: 0.1664 - val_acc: 0.9333 - test_loss: 0.1078 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 221 - loss: 0.093 - acc: 0.9833 - val_loss: 0.1655 - val_acc: 0.9333 - test_loss: 0.1072 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 222 - loss: 0.0924 - acc: 0.9833 - val_loss: 0.1647 - val_acc: 0.9333 - test_loss: 0.1066 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 223 - loss: 0.0918 - acc: 0.9833 - val_loss: 0.1639 - val_acc: 0.9333 - test_loss: 0.106 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 224 - loss: 0.0913 - acc: 0.9833 - val_loss: 0.163 - val_acc: 0.9333 - test_loss: 0.1054 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 225 - loss: 0.0907 - acc: 0.9833 - val_loss: 0.1622 - val_acc: 0.9333 - test_loss: 0.1048 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 226 - loss: 0.0902 - acc: 0.9833 - val_loss: 0.1615 - val_acc: 0.9333 - test_loss: 0.1043 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 227 - loss: 0.0897 - acc: 0.9833 - val_loss: 0.1607 - val_acc: 0.9556 - test_loss: 0.1037 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 228 - loss: 0.0892 - acc: 0.9833 - val_loss: 0.1599 - val_acc: 0.9556 - test_loss: 0.1031 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 229 - loss: 0.0886 - acc: 0.9833 - val_loss: 0.1592 - val_acc: 0.9556 - test_loss: 0.1026 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 230 - loss: 0.0881 - acc: 0.9833 - val_loss: 0.1584 - val_acc: 0.9556 - test_loss: 0.1021 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 231 - loss: 0.0877 - acc: 0.9833 - val_loss: 0.1577 - val_acc: 0.9556 - test_loss: 0.1015 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 232 - loss: 0.0872 - acc: 0.9833 - val_loss: 0.157 - val_acc: 0.9556 - test_loss: 0.101 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 233 - loss: 0.0867 - acc: 0.9833 - val_loss: 0.1563 - val_acc: 0.9556 - test_loss: 0.1005 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 234 - loss: 0.0862 - acc: 0.9833 - val_loss: 0.1556 - val_acc: 0.9556 - test_loss: 0.1 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 235 - loss: 0.0858 - acc: 0.9833 - val_loss: 0.1549 - val_acc: 0.9556 - test_loss: 0.0995 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 236 - loss: 0.0853 - acc: 0.9833 - val_loss: 0.1542 - val_acc: 0.9556 - test_loss: 0.099 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 237 - loss: 0.0849 - acc: 0.9833 - val_loss: 0.1535 - val_acc: 0.9556 - test_loss: 0.0985 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 238 - loss: 0.0845 - acc: 0.9833 - val_loss: 0.1529 - val_acc: 0.9556 - test_loss: 0.0981 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 239 - loss: 0.084 - acc: 0.9833 - val_loss: 0.1522 - val_acc: 0.9556 - test_loss: 0.0976 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 240 - loss: 0.0836 - acc: 0.9833 - val_loss: 0.1516 - val_acc: 0.9556 - test_loss: 0.0971 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 241 - loss: 0.0832 - acc: 0.9833 - val_loss: 0.1509 - val_acc: 0.9556 - test_loss: 0.0967 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 242 - loss: 0.0828 - acc: 0.9833 - val_loss: 0.1503 - val_acc: 0.9556 - test_loss: 0.0962 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 243 - loss: 0.0824 - acc: 0.9833 - val_loss: 0.1497 - val_acc: 0.9556 - test_loss: 0.0957 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 244 - loss: 0.082 - acc: 0.9833 - val_loss: 0.1491 - val_acc: 0.9556 - test_loss: 0.0953 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 245 - loss: 0.0816 - acc: 0.9833 - val_loss: 0.1485 - val_acc: 0.9556 - test_loss: 0.0949 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 246 - loss: 0.0813 - acc: 0.9833 - val_loss: 0.1479 - val_acc: 0.9556 - test_loss: 0.0944 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 247 - loss: 0.0809 - acc: 0.9833 - val_loss: 0.1473 - val_acc: 0.9556 - test_loss: 0.094 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 248 - loss: 0.0805 - acc: 0.9833 - val_loss: 0.1467 - val_acc: 0.9556 - test_loss: 0.0936 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 249 - loss: 0.0801 - acc: 0.9833 - val_loss: 0.1461 - val_acc: 0.9333 - test_loss: 0.0932 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# Epoch 250 - loss: 0.0798 - acc: 0.9833 - val_loss: 0.1456 - val_acc: 0.9333 - test_loss: 0.0928 - test_acc: 0.9778 - test_error: 0.0222 - epochsWithoutImprovement 0
# The ANN corespond to the epoch 250
#
# Training architecture: [4, 8, 2]
# Epoch 0 - loss: 1.1529 - val_loss: 1.1413 - test_loss: 1.1254
# Epoch 1 - loss: 1.1442 - acc: 0.3167 - val_loss: 1.1337 - val_acc: 0.3333 - test_loss: 1.1193 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 2 - loss: 1.1363 - acc: 0.3167 - val_loss: 1.1269 - val_acc: 0.3333 - test_loss: 1.1139 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 3 - loss: 1.1293 - acc: 0.3167 - val_loss: 1.1209 - val_acc: 0.3333 - test_loss: 1.1093 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 4 - loss: 1.1232 - acc: 0.3167 - val_loss: 1.1157 - val_acc: 0.3333 - test_loss: 1.1054 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 5 - loss: 1.1178 - acc: 0.3167 - val_loss: 1.1113 - val_acc: 0.3333 - test_loss: 1.1023 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 6 - loss: 1.1131 - acc: 0.3167 - val_loss: 1.1076 - val_acc: 0.3333 - test_loss: 1.0998 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 7 - loss: 1.1092 - acc: 0.3167 - val_loss: 1.1046 - val_acc: 0.3333 - test_loss: 1.0979 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 8 - loss: 1.106 - acc: 0.3167 - val_loss: 1.1022 - val_acc: 0.3333 - test_loss: 1.0966 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 9 - loss: 1.1033 - acc: 0.3167 - val_loss: 1.1003 - val_acc: 0.3333 - test_loss: 1.0958 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 10 - loss: 1.1012 - acc: 0.3167 - val_loss: 1.0989 - val_acc: 0.3333 - test_loss: 1.0954 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 11 - loss: 1.0996 - acc: 0.3167 - val_loss: 1.098 - val_acc: 0.3333 - test_loss: 1.0954 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 12 - loss: 1.0983 - acc: 0.3167 - val_loss: 1.0974 - val_acc: 0.3333 - test_loss: 1.0957 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 13 - loss: 1.0974 - acc: 0.3167 - val_loss: 1.0971 - val_acc: 0.3333 - test_loss: 1.0962 - test_acc: 0.3556 - test_error: 0.6444 - epochsWithoutImprovement 0
# Epoch 14 - loss: 1.0968 - acc: 0.35 - val_loss: 1.097 - val_acc: 0.3333 - test_loss: 1.0969 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 15 - loss: 1.0964 - acc: 0.35 - val_loss: 1.0972 - val_acc: 0.3333 - test_loss: 1.0977 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 1
# Epoch 16 - loss: 1.0962 - acc: 0.35 - val_loss: 1.0974 - val_acc: 0.3333 - test_loss: 1.0985 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 2
# Epoch 17 - loss: 1.0961 - acc: 0.35 - val_loss: 1.0977 - val_acc: 0.3333 - test_loss: 1.0994 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 3
# Epoch 18 - loss: 1.0961 - acc: 0.35 - val_loss: 1.0981 - val_acc: 0.3333 - test_loss: 1.1003 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 4
# Epoch 19 - loss: 1.0962 - acc: 0.35 - val_loss: 1.0985 - val_acc: 0.3333 - test_loss: 1.1011 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 5
# Epoch 20 - loss: 1.0962 - acc: 0.35 - val_loss: 1.0989 - val_acc: 0.3333 - test_loss: 1.1019 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 6
# Epoch 21 - loss: 1.0963 - acc: 0.35 - val_loss: 1.0992 - val_acc: 0.3333 - test_loss: 1.1025 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 7
# Epoch 22 - loss: 1.0964 - acc: 0.35 - val_loss: 1.0995 - val_acc: 0.3333 - test_loss: 1.1031 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 8
# Epoch 23 - loss: 1.0964 - acc: 0.35 - val_loss: 1.0997 - val_acc: 0.3333 - test_loss: 1.1035 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 9
# Epoch 24 - loss: 1.0965 - acc: 0.35 - val_loss: 1.0999 - val_acc: 0.3333 - test_loss: 1.1039 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 10
# Epoch 25 - loss: 1.0964 - acc: 0.35 - val_loss: 1.0999 - val_acc: 0.3333 - test_loss: 1.1041 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 11
# Epoch 26 - loss: 1.0964 - acc: 0.35 - val_loss: 1.0999 - val_acc: 0.3333 - test_loss: 1.1042 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 12
# Epoch 27 - loss: 1.0962 - acc: 0.35 - val_loss: 1.0999 - val_acc: 0.3333 - test_loss: 1.1041 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 13
# Epoch 28 - loss: 1.0961 - acc: 0.35 - val_loss: 1.0997 - val_acc: 0.3333 - test_loss: 1.104 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 14
# Epoch 29 - loss: 1.0959 - acc: 0.35 - val_loss: 1.0995 - val_acc: 0.3333 - test_loss: 1.1038 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 15
# Epoch 30 - loss: 1.0957 - acc: 0.35 - val_loss: 1.0993 - val_acc: 0.3333 - test_loss: 1.1034 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 16
# Epoch 31 - loss: 1.0954 - acc: 0.35 - val_loss: 1.0989 - val_acc: 0.3333 - test_loss: 1.103 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 17
# Epoch 32 - loss: 1.0951 - acc: 0.35 - val_loss: 1.0986 - val_acc: 0.3333 - test_loss: 1.1025 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 18
# Epoch 33 - loss: 1.0948 - acc: 0.35 - val_loss: 1.0981 - val_acc: 0.3333 - test_loss: 1.1019 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 19
# Epoch 34 - loss: 1.0944 - acc: 0.35 - val_loss: 1.0977 - val_acc: 0.3333 - test_loss: 1.1013 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 20
# ⏹ Early stopping triggered after 34 epochs (no improvement for 20 epochs).
# The ANN corespond to the epoch 14
#
# Training architecture: [6, 12, 6, 2]
# Epoch 0 - loss: 1.1629 - val_loss: 1.1701 - test_loss: 1.1794
# Epoch 1 - loss: 1.1512 - acc: 0.35 - val_loss: 1.1583 - val_acc: 0.3333 - test_loss: 1.1675 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 2 - loss: 1.1406 - acc: 0.35 - val_loss: 1.1474 - val_acc: 0.3333 - test_loss: 1.1562 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 3 - loss: 1.1311 - acc: 0.35 - val_loss: 1.1375 - val_acc: 0.3333 - test_loss: 1.1456 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 4 - loss: 1.1229 - acc: 0.35 - val_loss: 1.1287 - val_acc: 0.3333 - test_loss: 1.1361 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 5 - loss: 1.116 - acc: 0.35 - val_loss: 1.1212 - val_acc: 0.3333 - test_loss: 1.1279 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 6 - loss: 1.1103 - acc: 0.35 - val_loss: 1.115 - val_acc: 0.3333 - test_loss: 1.1209 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# Epoch 7 - loss: 1.1059 - acc: 0.35 - val_loss: 1.11 - val_acc: 0.3333 - test_loss: 1.1153 - test_acc: 0.3111 - test_error: 0.6889 - epochsWithoutImprovement 0
# ...
# Epoch 154 - loss: 0.5635 - acc: 0.65 - val_loss: 0.5616 - val_acc: 0.6667 - test_loss: 0.5343 - test_acc: 0.6889 - test_error: 0.3111 - epochsWithoutImprovement 0
# Epoch 155 - loss: 0.5613 - acc: 0.65 - val_loss: 0.5594 - val_acc: 0.6667 - test_loss: 0.5322 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 156 - loss: 0.5592 - acc: 0.6833 - val_loss: 0.5572 - val_acc: 0.6667 - test_loss: 0.5301 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 157 - loss: 0.5571 - acc: 0.7 - val_loss: 0.5551 - val_acc: 0.6889 - test_loss: 0.5281 - test_acc: 0.7111 - test_error: 0.2889 - epochsWithoutImprovement 0
# Epoch 158 - loss: 0.5551 - acc: 0.7 - val_loss: 0.5531 - val_acc: 0.7111 - test_loss: 0.5262 - test_acc: 0.7333 - test_error: 0.2667 - epochsWithoutImprovement 0
# Epoch 159 - loss: 0.5532 - acc: 0.7 - val_loss: 0.5512 - val_acc: 0.7111 - test_loss: 0.5243 - test_acc: 0.7556 - test_error: 0.2444 - epochsWithoutImprovement 0
# Epoch 160 - loss: 0.5513 - acc: 0.8 - val_loss: 0.5493 - val_acc: 0.7111 - test_loss: 0.5225 - test_acc: 0.8 - test_error: 0.2 - epochsWithoutImprovement 0
# Epoch 161 - loss: 0.5495 - acc: 0.8167 - val_loss: 0.5475 - val_acc: 0.8 - test_loss: 0.5207 - test_acc: 0.8444 - test_error: 0.1556 - epochsWithoutImprovement 0
# Epoch 162 - loss: 0.5478 - acc: 0.8833 - val_loss: 0.5457 - val_acc: 0.7778 - test_loss: 0.519 - test_acc: 0.8667 - test_error: 0.1333 - epochsWithoutImprovement 0
# Epoch 163 - loss: 0.5461 - acc: 0.8833 - val_loss: 0.544 - val_acc: 0.8 - test_loss: 0.5174 - test_acc: 0.8889 - test_error: 0.1111 - epochsWithoutImprovement 0
# Epoch 164 - loss: 0.5445 - acc: 0.9 - val_loss: 0.5424 - val_acc: 0.8222 - test_loss: 0.5158 - test_acc: 0.8889 - test_error: 0.1111 - epochsWithoutImprovement 0
# Epoch 165 - loss: 0.5429 - acc: 0.9 - val_loss: 0.5408 - val_acc: 0.8667 - test_loss: 0.5143 - test_acc: 0.9111 - test_error: 0.0889 - epochsWithoutImprovement 0
# Epoch 166 - loss: 0.5413 - acc: 0.9 - val_loss: 0.5392 - val_acc: 0.8444 - test_loss: 0.5128 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 167 - loss: 0.5398 - acc: 0.9 - val_loss: 0.5377 - val_acc: 0.8889 - test_loss: 0.5113 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 168 - loss: 0.5383 - acc: 0.9 - val_loss: 0.5362 - val_acc: 0.8667 - test_loss: 0.5099 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 169 - loss: 0.5369 - acc: 0.9333 - val_loss: 0.5348 - val_acc: 0.8444 - test_loss: 0.5086 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 170 - loss: 0.5355 - acc: 0.9167 - val_loss: 0.5334 - val_acc: 0.8667 - test_loss: 0.5072 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 171 - loss: 0.5341 - acc: 0.9167 - val_loss: 0.532 - val_acc: 0.8667 - test_loss: 0.5059 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 172 - loss: 0.5328 - acc: 0.9333 - val_loss: 0.5307 - val_acc: 0.8889 - test_loss: 0.5047 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 173 - loss: 0.5315 - acc: 0.95 - val_loss: 0.5294 - val_acc: 0.8889 - test_loss: 0.5034 - test_acc: 0.9556 - test_error: 0.0444 - epochsWithoutImprovement 0
# Epoch 174 - loss: 0.5302 - acc: 0.95 - val_loss: 0.5281 - val_acc: 0.8889 - test_loss: 0.5022 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 175 - loss: 0.529 - acc: 0.95 - val_loss: 0.5269 - val_acc: 0.8889 - test_loss: 0.501 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 176 - loss: 0.5278 - acc: 0.95 - val_loss: 0.5257 - val_acc: 0.8667 - test_loss: 0.4999 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 177 - loss: 0.5266 - acc: 0.95 - val_loss: 0.5245 - val_acc: 0.8667 - test_loss: 0.4988 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 178 - loss: 0.5254 - acc: 0.95 - val_loss: 0.5233 - val_acc: 0.8667 - test_loss: 0.4977 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 179 - loss: 0.5243 - acc: 0.95 - val_loss: 0.5222 - val_acc: 0.8667 - test_loss: 0.4966 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 180 - loss: 0.5232 - acc: 0.95 - val_loss: 0.5211 - val_acc: 0.8667 - test_loss: 0.4955 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 181 - loss: 0.522 - acc: 0.9667 - val_loss: 0.52 - val_acc: 0.8667 - test_loss: 0.4945 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 182 - loss: 0.521 - acc: 0.9667 - val_loss: 0.5189 - val_acc: 0.8667 - test_loss: 0.4935 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 183 - loss: 0.5199 - acc: 0.9667 - val_loss: 0.5179 - val_acc: 0.8667 - test_loss: 0.4924 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 184 - loss: 0.5188 - acc: 0.9667 - val_loss: 0.5168 - val_acc: 0.8667 - test_loss: 0.4915 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 185 - loss: 0.5178 - acc: 0.9667 - val_loss: 0.5158 - val_acc: 0.8889 - test_loss: 0.4905 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 186 - loss: 0.5167 - acc: 0.9667 - val_loss: 0.5148 - val_acc: 0.8889 - test_loss: 0.4895 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 187 - loss: 0.5157 - acc: 0.9667 - val_loss: 0.5138 - val_acc: 0.8667 - test_loss: 0.4886 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 188 - loss: 0.5147 - acc: 0.9667 - val_loss: 0.5128 - val_acc: 0.8667 - test_loss: 0.4876 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 189 - loss: 0.5137 - acc: 0.9667 - val_loss: 0.5119 - val_acc: 0.8667 - test_loss: 0.4867 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 190 - loss: 0.5127 - acc: 0.9667 - val_loss: 0.5109 - val_acc: 0.8667 - test_loss: 0.4858 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 191 - loss: 0.5117 - acc: 0.9667 - val_loss: 0.51 - val_acc: 0.8667 - test_loss: 0.4848 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 192 - loss: 0.5107 - acc: 0.9667 - val_loss: 0.5091 - val_acc: 0.8667 - test_loss: 0.4839 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 193 - loss: 0.5097 - acc: 0.9667 - val_loss: 0.5081 - val_acc: 0.8667 - test_loss: 0.483 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 194 - loss: 0.5087 - acc: 0.9667 - val_loss: 0.5072 - val_acc: 0.8667 - test_loss: 0.4821 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 195 - loss: 0.5078 - acc: 0.9667 - val_loss: 0.5063 - val_acc: 0.8667 - test_loss: 0.4812 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 196 - loss: 0.5068 - acc: 0.9667 - val_loss: 0.5054 - val_acc: 0.8667 - test_loss: 0.4803 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 197 - loss: 0.5058 - acc: 0.9667 - val_loss: 0.5045 - val_acc: 0.8667 - test_loss: 0.4794 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 198 - loss: 0.5048 - acc: 0.9667 - val_loss: 0.5037 - val_acc: 0.8667 - test_loss: 0.4785 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 199 - loss: 0.5038 - acc: 0.9667 - val_loss: 0.5028 - val_acc: 0.8667 - test_loss: 0.4776 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 200 - loss: 0.5028 - acc: 0.9667 - val_loss: 0.5019 - val_acc: 0.8667 - test_loss: 0.4767 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 201 - loss: 0.5018 - acc: 0.9667 - val_loss: 0.501 - val_acc: 0.8667 - test_loss: 0.4758 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 202 - loss: 0.5008 - acc: 0.9667 - val_loss: 0.5002 - val_acc: 0.8667 - test_loss: 0.4749 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 203 - loss: 0.4998 - acc: 0.9667 - val_loss: 0.4993 - val_acc: 0.8667 - test_loss: 0.474 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 204 - loss: 0.4988 - acc: 0.9667 - val_loss: 0.4984 - val_acc: 0.8667 - test_loss: 0.473 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 205 - loss: 0.4978 - acc: 0.9667 - val_loss: 0.4975 - val_acc: 0.8667 - test_loss: 0.4721 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 206 - loss: 0.4967 - acc: 0.9667 - val_loss: 0.4967 - val_acc: 0.8667 - test_loss: 0.4712 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 207 - loss: 0.4956 - acc: 0.9667 - val_loss: 0.4958 - val_acc: 0.8667 - test_loss: 0.4702 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 208 - loss: 0.4946 - acc: 0.9667 - val_loss: 0.4949 - val_acc: 0.8667 - test_loss: 0.4692 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 209 - loss: 0.4935 - acc: 0.9667 - val_loss: 0.4941 - val_acc: 0.8667 - test_loss: 0.4682 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 210 - loss: 0.4924 - acc: 0.9667 - val_loss: 0.4932 - val_acc: 0.8667 - test_loss: 0.4672 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 211 - loss: 0.4912 - acc: 0.9667 - val_loss: 0.4923 - val_acc: 0.8667 - test_loss: 0.4662 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 212 - loss: 0.4901 - acc: 0.9667 - val_loss: 0.4914 - val_acc: 0.8667 - test_loss: 0.4651 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 213 - loss: 0.4889 - acc: 0.9667 - val_loss: 0.4905 - val_acc: 0.8667 - test_loss: 0.464 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 214 - loss: 0.4877 - acc: 0.9667 - val_loss: 0.4896 - val_acc: 0.8667 - test_loss: 0.463 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 215 - loss: 0.4865 - acc: 0.9667 - val_loss: 0.4887 - val_acc: 0.8667 - test_loss: 0.4618 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 216 - loss: 0.4852 - acc: 0.9667 - val_loss: 0.4878 - val_acc: 0.8667 - test_loss: 0.4607 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 217 - loss: 0.4839 - acc: 0.9667 - val_loss: 0.4868 - val_acc: 0.8444 - test_loss: 0.4595 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 218 - loss: 0.4826 - acc: 0.9667 - val_loss: 0.4859 - val_acc: 0.8667 - test_loss: 0.4583 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 219 - loss: 0.4813 - acc: 0.9667 - val_loss: 0.485 - val_acc: 0.8667 - test_loss: 0.4571 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 220 - loss: 0.48 - acc: 0.9667 - val_loss: 0.484 - val_acc: 0.8667 - test_loss: 0.4559 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 221 - loss: 0.4786 - acc: 0.9667 - val_loss: 0.4831 - val_acc: 0.8667 - test_loss: 0.4546 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 222 - loss: 0.4772 - acc: 0.9667 - val_loss: 0.4821 - val_acc: 0.8667 - test_loss: 0.4533 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 223 - loss: 0.4757 - acc: 0.9667 - val_loss: 0.4811 - val_acc: 0.8667 - test_loss: 0.452 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 224 - loss: 0.4742 - acc: 0.9667 - val_loss: 0.4801 - val_acc: 0.8667 - test_loss: 0.4506 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 225 - loss: 0.4728 - acc: 0.95 - val_loss: 0.4792 - val_acc: 0.8667 - test_loss: 0.4493 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 226 - loss: 0.4712 - acc: 0.95 - val_loss: 0.4782 - val_acc: 0.8667 - test_loss: 0.4479 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 227 - loss: 0.4697 - acc: 0.95 - val_loss: 0.4772 - val_acc: 0.8667 - test_loss: 0.4464 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 228 - loss: 0.4681 - acc: 0.95 - val_loss: 0.4761 - val_acc: 0.8667 - test_loss: 0.445 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 229 - loss: 0.4665 - acc: 0.95 - val_loss: 0.4751 - val_acc: 0.8667 - test_loss: 0.4435 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 230 - loss: 0.4649 - acc: 0.95 - val_loss: 0.4741 - val_acc: 0.8889 - test_loss: 0.442 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 231 - loss: 0.4632 - acc: 0.95 - val_loss: 0.4731 - val_acc: 0.8889 - test_loss: 0.4405 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 232 - loss: 0.4615 - acc: 0.95 - val_loss: 0.472 - val_acc: 0.8889 - test_loss: 0.439 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 233 - loss: 0.4598 - acc: 0.95 - val_loss: 0.471 - val_acc: 0.8889 - test_loss: 0.4375 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 234 - loss: 0.4581 - acc: 0.95 - val_loss: 0.4699 - val_acc: 0.8889 - test_loss: 0.4359 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 235 - loss: 0.4564 - acc: 0.95 - val_loss: 0.4689 - val_acc: 0.8889 - test_loss: 0.4344 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 236 - loss: 0.4546 - acc: 0.95 - val_loss: 0.4678 - val_acc: 0.8889 - test_loss: 0.4328 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 237 - loss: 0.4528 - acc: 0.95 - val_loss: 0.4668 - val_acc: 0.8889 - test_loss: 0.4312 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 238 - loss: 0.451 - acc: 0.95 - val_loss: 0.4657 - val_acc: 0.8889 - test_loss: 0.4296 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 239 - loss: 0.4491 - acc: 0.95 - val_loss: 0.4646 - val_acc: 0.8889 - test_loss: 0.428 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 240 - loss: 0.4473 - acc: 0.95 - val_loss: 0.4635 - val_acc: 0.8889 - test_loss: 0.4264 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 241 - loss: 0.4454 - acc: 0.95 - val_loss: 0.4624 - val_acc: 0.8889 - test_loss: 0.4248 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 242 - loss: 0.4435 - acc: 0.9667 - val_loss: 0.4613 - val_acc: 0.8667 - test_loss: 0.4232 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 243 - loss: 0.4416 - acc: 0.9667 - val_loss: 0.4602 - val_acc: 0.8444 - test_loss: 0.4215 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 244 - loss: 0.4397 - acc: 0.9667 - val_loss: 0.4591 - val_acc: 0.8444 - test_loss: 0.4199 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 245 - loss: 0.4378 - acc: 0.9667 - val_loss: 0.458 - val_acc: 0.8444 - test_loss: 0.4182 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 246 - loss: 0.4358 - acc: 0.9667 - val_loss: 0.4569 - val_acc: 0.8444 - test_loss: 0.4166 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 247 - loss: 0.4339 - acc: 0.9667 - val_loss: 0.4558 - val_acc: 0.8444 - test_loss: 0.4149 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 248 - loss: 0.4319 - acc: 0.9667 - val_loss: 0.4546 - val_acc: 0.8444 - test_loss: 0.4132 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 249 - loss: 0.4299 - acc: 0.9667 - val_loss: 0.4535 - val_acc: 0.8667 - test_loss: 0.4115 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# Epoch 250 - loss: 0.4279 - acc: 0.9667 - val_loss: 0.4523 - val_acc: 0.8667 - test_loss: 0.4098 - test_acc: 0.9333 - test_error: 0.0667 - epochsWithoutImprovement 0
# The ANN corespond to the epoch 250

# %% [markdown]
# ### Question 3.2
# > ❓ Has the test error always decreased or has there come a point where it has started to increase?

# %% [markdown]
# **~~`The error has increased with all the topologies at some point. In all the topologies, at some point the test error increase to 0.7 from a lower value.`~~**
#
# No.At some point the test error has increased only with some of the topologies . In some of the topologies, like in topologies [[8,4,2,2],[4,8,2],[16,8,4]] the test error decreases for some epochs then it increases again.

# %% [markdown]
# ### Question 3.3
# > ❓ How do the 3 precision values evolve?

# %% [markdown]
# **~~Precision per each target class or per each dataset?
# `The training accuracy and the validation accuracy always increase. However, the test accuracy starts at a low value, then it decrase a little bit  and finally, the ANN starts to generalize its knowledge and the test accuracy increases.`~~**
#
# As evident from the plots above, there is a strong dependence of the NN precisions outcomes on the neural network topology.
# Down below a syntethic resume of the NN training outcomes.
#
# **Note**
# Due to the random initialization of the NN weights the results may vary at each run so that the table below may vary as well.
#
#
# Training Summary — Architecture [10,5]
# | Epoch Range | Train Loss  | Val Loss  | Test Loss|
# |-------------|-------------|-----------|----------|
# |0–250        |  decrease   |  decrease | decrease |  Model converging
#
# Training Summary — Architecture [5, 3]
# | Epoch Range | Train Loss  | Val Loss  | Test Loss|
# |-------------|-------------|-----------|----------|
# |0–250        |  decrease   |  decrease | decrease |  Model converging and generalizing
#
#
# Training Summary — Architecture [8, 4, 2, 2]
# | Epoch Range | Train Loss  | Val Loss  | Test Loss|
# |-------------|-------------|-----------|----------|
# | 0–13        | decrease    |  decrease | decrease |
# | 14–20       | stable      |  increase | increase |
# | 21–33       | stable      | stable     | stable  | No improvement → Early stopping |
#
# Training Summary — Architecture [4, 8, 2]
# | Epoch Range | Train Loss  | Val Loss  | Test Loss|
# |-------------|-------------|-----------|----------|
# | 0–10        | decrease    |  decrease | decrease |
# | 11–14       | stable      |  stable   | stable   |
# | 15–34       | stable      | increase  | increase  | No improvement → Early stopping |
#
#
# Training Summary — Architecture [6, 12, 6, 2]
# | Epoch Range | Train Loss  | Val Loss  | Test Loss|
# |-------------|-------------|-----------|----------|
# |0–250        |  decrease   |  decrease | decrease | Model converging and generalizing
#
#
# Training Summary — Architecture [16, 8, 4]
# | Epoch Range | Train Loss  | Val Loss  | Test Loss|
# |-------------|-------------|-----------|----------|
# | 0–10        | decrease    |  decrease | decrease |
# | 11–14       | stable      |  stable   | stable   |
# | 15–34       | stable      | increase  | increase  | No improvement → Early stopping |
#
# Training Summary — Architecture [20, 10, 5, 2]
# | Epoch Range | Train Loss  | Val Loss  | Test Loss|
# |-------------|-------------|-----------|----------|
# |0–250        |  decrease   |  decrease | decrease | Model converging and generalizing

# %% [markdown]
# ### Question 3.4
# > ❓ Which criteria usually stop the training? Why?

# %% [markdown]
# **~~Half of the times the stop criteria is the early stopping, which happens because the validation loss does not improve for 20 epochs. The other half of the times, the training reachs the maximun number of training epochs.`~~**
#
# It strictly depends on the architecture that we set.When setting the architectures  [[8,4,2,2],[4,8,2],[6,8,4]]  the early stopping is triggered while in the remaining cases the training process continues till the defined number of epochs.
# The termination of the process is triggered in the case that the NN does not decrease the validation loss for a predefined number of epochs, 20 in our cases.

# %% [markdown]
# ### Question 3.5
# > ❓ To which cycle does the ANN returned by the function correspond?

# %% [markdown]
# | Topology        | Cycle |
# |------------------|-------|
# | [10, 5]          | 250   |
# | [5, 3]           | 250   |
# | [8, 4, 2, 2]     | 13    |
# | [4, 8, 2]        | 14    |
# | [6, 12, 6, 2]    | 250   |
# | [16, 8, 4]       | 14    |
# | [20, 10, 5, 2]   | 250   |
#
#
# **Note**
# Due to the random initialization of the NN weights the results may vary at each run.
